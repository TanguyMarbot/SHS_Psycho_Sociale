# %%
import pandas as pd

# %%
test = pd.read_csv("CD_dat_raw.csv")

df = test[test["progress"] == "100"]

# %%
df[["duration", "progress"]] = df[["duration", "progress"]].apply(pd.to_numeric)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_15752/3515230605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["duration"]] = df[["duration"]].apply(pd.to_numeric)

# %%
df[df["progress"] == "100"].sort_values(by=['duration'], ascending=True)
# Out:
#           startDate         endDate status        ipAddress progress  \
# 618  01.05.23 08:41  01.05.23 08:41      0  178.197.193.195      100
# 100  15.04.23 11:49  15.04.23 11:49      0   185.25.195.154      100
# 2    06.04.23 06:32  06.04.23 06:32      0  128.179.144.223      100
# 242  18.04.23 13:20  18.04.23 13:21      0  176.166.212.148      100
# 1    05.04.23 12:30  05.04.23 12:30      0   62.202.188.144      100
# ..              ...             ...    ...              ...      ...
# 38   11.04.23 09:41  11.04.23 11:58      0   80.200.208.148      100
# 542  26.04.23 09:58  26.04.23 12:18      0      188.4.86.61      100
# 222  18.04.23 06:17  18.04.23 10:25      0   92.159.188.119      100
# 122  16.04.23 03:10  16.04.23 14:56      0     93.30.81.178      100
# 91   13.04.23 07:56  14.04.23 01:51      0  178.195.154.104      100
#
#      duration finished    recordedDate          _recordId recipientLastName  \
# ...
